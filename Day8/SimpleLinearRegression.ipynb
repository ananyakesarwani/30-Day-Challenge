# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
dataset = pd.read_csv("Salary_Data.csv")
X = dataset.iloc[:,:-1].values
Y = dataset.iloc[:,-1].values

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=1/3, random_state=0)

# %%
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = regressor.predict(X_test)

# %%
plt.scatter(X_train, Y_train, color ='red')
plt.plot(X_train, regressor.predict(X_train),color='green')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid()
plt.show()

# %%
plt.scatter(X_test, Y_test, color ='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')  #no need to replace with X_test as linear equation remains same
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.grid()
plt.show()

# %%
#Making Single Prediction (e.g salary for 12 years of experience)
print(regressor.predict([[12]]))
# Out:
# [138967.5015615]

# %%
#Getting the final linear regression equation with values pf coefficients
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [9345.94244312]
# 26816.19224403119

# %%
# equation   Salary=9345.94244312 * yearsOfExperience + 26816.19224403119
